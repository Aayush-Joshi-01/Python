# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import pyspark as psk

# %%
co2df = pd.read_csv("CarbonDiOxide_Emmissions_Data.csv")
co2df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3767956.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3783940.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3800954.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3818038.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 47410     Zimbabwe  2018      ZWE  15052191.0  2.678627e+10       0.558
# 47411     Zimbabwe  2019      ZWE  15354606.0  2.514642e+10       0.473
# 47412     Zimbabwe  2020      ZWE  15669663.0  2.317871e+10       0.496
# 47413     Zimbabwe  2021      ZWE  15993525.0  2.514009e+10       0.531
# 47414     Zimbabwe  2022      ZWE  16320539.0  2.590159e+10       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
co2df.dtypes
# Out:
# country                         object
# year                             int64
# iso_code                        object
# population                     float64
# gdp                            float64
#                                 ...
# temperature_change_from_n2o    float64
# total_ghg                      float64
# total_ghg_excluding_lucf       float64
# trade_co2                      float64
# trade_co2_share                float64
# Length: 79, dtype: object

# %%
grouped_df = pd.DataFrame(co2df.groupby('country')['co2'].sum())
grouped_df
# Out:
#                            co2
# country
# Afghanistan            230.757
# Africa               51012.393
# Africa (GCP)         51011.964
# Albania                298.889
# Algeria               5076.843
# ...                        ...
# Wallis and Futuna        0.798
# World              1772867.527
# Yemen                  687.572
# Zambia                 268.456
# Zimbabwe               798.693
#
# [261 rows x 1 columns]

# %%
co2df_desc = pd.read_csv("Co2_Data_Desc.csv")
co2df_desc
# Out:
#                          column  \
# 0                       country
# 1                          year
# 2                      iso_code
# 3                    population
# 4                           gdp
# ..                          ...
# 74  temperature_change_from_n2o
# 75                    total_ghg
# 76     total_ghg_excluding_lucf
# 77                    trade_co2
# 78              trade_co2_share
#
#                                           description  \
# 0                      Country - Geographic location.
# 1                         Year - Year of observation.
# 2   ISO code - ISO 3166-1 alpha-3 three-letter cou...
# 3   Population - Population by country, available ...
# 4   Gross domestic product (GDP) - This data is ad...
# ..                                                ...
# 74  Change in global mean surface temperature caus...
# 75  Total greenhouse gas emissions including land-...
# 76  Total greenhouse gas emissions excluding land-...
# ...

# %%
data_df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)
data_df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
data_df['Age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages_df = pd.Series([22, 36, 58], name="Age")
ages_df
# Out:
# 0    22
# 1    36
# 2    58
# Name: Age, dtype: int64

# %%
int(data_df['Age'].max())
# Out:
# 58

# %%
data_list= [['Alice', 25, 'New York'], 
        ['Bob', 30, 'Los Angeles'], 
        ['Charlie', 28, 'Chicago']]
df_list = pd.DataFrame(data_list, columns=['Name', 'Age', 'City'])
print(df_list)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   28      Chicago

# %%
df_list.set_index('Name', inplace=False)
# Out:
#          Age         City
# Name
# Alice     25     New York
# Bob       30  Los Angeles
# Charlie   28      Chicago

# %%
df_list
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   28      Chicago

# %%
df_list.set_index('Name', inplace=True)
df_list
# Out:
#          Age         City
# Name
# Alice     25     New York
# Bob       30  Los Angeles
# Charlie   28      Chicago
