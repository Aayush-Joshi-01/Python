# %%
! pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/user/Python_Training/Week-10/09 July/Prods/Assignments/Self/TCS.csv")
df
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 0     2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00
# 1     2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30
# 2     2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55
# 3     2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00
# 4     2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00
# ...          ...    ...    ...         ...      ...      ...      ...
# 4134  2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05
# 4135  2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00
# 4136  2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00
# 4137  2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50
# 4138  2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# ...

# %%
for i in df.itertuples(name='Date'):
    print(i)
# Out:
# Date(Index=0, Date='2004-08-25', Symbol='TCS', Series='EQ', _4=850.0, Open=1198.7, High=1198.7, Low=979.0, Last=985.0, Close=987.95, VWAP=1008.32, Volume=17116372, Turnover=1725876095745000.0, Trades=nan, _14=5206360, _15=0.3042)
# Date(Index=1, Date='2004-08-26', Symbol='TCS', Series='EQ', _4=987.95, Open=992.0, High=997.0, Low=975.3, Last=976.85, Close=979.0, VWAP=985.65, Volume=5055400, Turnover=498286476730000.0, Trades=nan, _14=1294899, _15=0.2561)
# Date(Index=2, Date='2004-08-27', Symbol='TCS', Series='EQ', _4=979.0, Open=982.4, High=982.4, Low=958.55, Last=961.2, Close=962.65, VWAP=969.94, Volume=3830750, Turnover=371558603080000.0, Trades=nan, _14=976527, _15=0.2549)
# Date(Index=3, Date='2004-08-30', Symbol='TCS', Series='EQ', _4=962.65, Open=969.9, High=990.0, Low=965.0, Last=986.4, Close=986.75, VWAP=982.65, Volume=3058151, Turnover=300510633990000.0, Trades=nan, _14=701664, _15=0.2294)
# ...
