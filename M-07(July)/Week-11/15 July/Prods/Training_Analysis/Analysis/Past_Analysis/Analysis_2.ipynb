# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_data.csv')
df.head()
# Out:
#    Unnamed: 0  S.No   Emp ID                     Name  \
# 0           0     1  1014181             Mohd Manazir
# 1           1     2  1015340  Akash Sahadev Nandurkar
# 2           2     3  1015860           Paritosh Dimri
# 3           3     4  1009383      Krishnakant Bairagi
# 4           4     5  1012704       Amol Shivaji Palve
#
#                         EmailID Grade Resource Type  \
# 0         mohd.manazir@yash.com    E2     Permanent
# 1      akash.nandurkar@yash.com    E1     Permanent
# 2       paritosh.dimri@yash.com    E2     Permanent
# 3  krishnakant.bairagi@yash.com    E3     Permanent
# 4           amol.palve@yash.com    E2     Permanent
#
#                               Training Stack  \
# 0  Rest,Microservice,Docker,kubernetes,kafka
# 1  Rest,Microservice,Docker,kubernetes,kafka
# 2  Rest,Microservice,Docker,kubernetes,kafka
# 3                                      Junit
# 4                                      Junit
#
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df.head()
# Out:
#    S.No   Emp ID                     Name                       EmailID Grade  \
# 0     1  1014181             Mohd Manazir         mohd.manazir@yash.com    E2
# 1     2  1015340  Akash Sahadev Nandurkar      akash.nandurkar@yash.com    E1
# 2     3  1015860           Paritosh Dimri       paritosh.dimri@yash.com    E2
# 3     4  1009383      Krishnakant Bairagi  krishnakant.bairagi@yash.com    E3
# 4     5  1012704       Amol Shivaji Palve           amol.palve@yash.com    E2
#
#   Resource Type                             Training Stack  \
# 0     Permanent  Rest,Microservice,Docker,kubernetes,kafka
# 1     Permanent  Rest,Microservice,Docker,kubernetes,kafka
# 2     Permanent  Rest,Microservice,Docker,kubernetes,kafka
# 3     Permanent                                      Junit
# 4     Permanent                                      Junit
#
#                                        Training Name  \
# 0  BG4-BU5-Java-Merck(Rest,Microservice,Docker,ku...
# ...

# %%
def group_by_criteria_data(data, grouper_criteria):
    return data.groupby(grouper_criteria)['Name'].apply(list).to_dict()

def group_by_criteria_count(data, grouper_criteria):
    return data.groupby(grouper_criteria)['Name'].count()

# %%
data_grouped_by_criteria = group_by_criteria_data(df, 'All Skills')

# %%
list(data_grouped_by_criteria.items())
# Out:
# [("['java', 'management', 'microsoft', 'legacy']",
#   ['Santosh Ladkat',
#    'Manmohan Ubbey',
#    'Sankara Jilledimudi',
#    'Sambasivarao Damanaboina',
#    'Rajkumar Gehlot',
#    'Mrunali Zade',
#    'Praful Suryavanshi',
#    'Sachin Hodlur',
#    'Shaik Meeravali',
#    'Dhanya Sreedharan Pillai',
#    'Amar Vilas Sawant',
#    'Shaline Mishra',
#    'Rahul Kumar Soni',
#    'Vivek Kadam',
#    'Aman Kumar',
#    'Aarti Rupchand Shete',
#    'Vrushabh Abhaykumar Wakhariya',
#    'Ayushi Jain']),
#  ("['java', 'microsoft', 'legacy']", ['Mohammad Abul Aas']),
#  ("['java', 'microsoft']",
#   ['Sai Charan',
#    'Abhijeet Sable',
#    'Aditya S Sankar',
#    'Pallavi Jain',
#    'Budda Pavani']),
#  ("['java']",
#   ['Mohd Manazir',
#    'Akash Sahadev Nandurkar',
#    'Paritosh Dimri',
#    'Krishnakant Bairagi',
#    'Amol Shivaji Palve',
#    'Yogesh Nagora',
#    'Mayuri Nandkishorji Mundada',
#    'Vaibhav Prabhakar Shete',
#    'Devdatta Manoranjan Chilwant',
# ...

# %%
skills = ['java', 'aws', '.net', 'devops']

# %%
list_of_employee = []
for sk in skills:
    if sk in data_grouped_by_criteria.keys():
        print(sk)
        print(sk in data_grouped_by_criteria.keys())
        list_of_employee.append
    print(sk)
# Out:
# java
# aws
# .net
# devops

# %%
unique_skills = list(set(skill for sublist in data_grouped_by_criteria.keys() for skill in sublist))

print(unique_skills)
# Out:
# [']', 'a', 'r', 'i', 't', 'w', 'k', 's', 'o', ')', 'n', '&', 'p', 'v', 'e', 'b', '[', 'y', 'm', 'g', ' ', "'", '.', 'j', ',', 'l', 'u', 'f', 'd', 'h', '(', 'c']
