# %%
! pip install pandas

# %%
! pip install openpyxl

# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_excel("Training_CTR_Report2024.xlsx")

# %%
df.head()
# Out:
#    S.No   Emp ID                     Name                       EmailID Grade  \
# 0     1  1014181             Mohd Manazir         mohd.manazir@yash.com    E2
# 1     2  1015340  Akash Sahadev Nandurkar      akash.nandurkar@yash.com    E1
# 2     3  1015860           Paritosh Dimri       paritosh.dimri@yash.com    E2
# 3     4  1009383      Krishnakant Bairagi  krishnakant.bairagi@yash.com    E3
# 4     5  1012704       Amol Shivaji Palve           amol.palve@yash.com    E2
#
#   Resource Type                             Training Stack  \
# 0     Permanent  Rest,Microservice,Docker,kubernetes,kafka
# 1     Permanent  Rest,Microservice,Docker,kubernetes,kafka
# 2     Permanent  Rest,Microservice,Docker,kubernetes,kafka
# 3     Permanent                                      Junit
# 4     Permanent                                      Junit
#
#                                        Training Name  \
# 0  BG4-BU5-Java-Merck(Rest,Microservice,Docker,ku...
# ...

# %%
def clean_stack(skill_stack):
    if isinstance(skill_stack, str):
        # Replace any non-alphanumeric separator with a comma and then split into list
        cleaned_stack = skill_stack.replace(';', ',').replace('/', ',').replace('+', ',').replace('(', ',').replace(')', ' ').split(',')
        # Strip whitespace from each element
        cleaned_stack = [stack.strip() for stack in cleaned_stack]
        return cleaned_stack
    return skill_stack

# %%
df['Training Stack'] = df['Training Stack'].apply(clean_stack)

# %%
df.tail()
# Out:
#      S.No   Emp ID                           Name  \
# 147   264  1100298         Mayur Madhukar Karmude
# 148   265  1100299     Charusheela Subhash Chavan
# 149   266  1100314     Varsha Chandrakant Aherkar
# 150   267  1100319  Shivdarshan Vishnukant Landge
# 151   268  1100332          Mahesh Tukaram Surnar
#
#                          EmailID Grade Resource Type Training Stack  \
# 147       mayur.karmude@yash.com    E1     Permanent  [Java, React]
# 148  charusheela.chavan@yash.com    E1     Permanent  [Java, React]
# 149      varsha.aherkar@yash.com    E1     Permanent  [Java, React]
# 150  shivdarshan.landge@yash.com    E1     Permanent  [Java, React]
# 151       mahesh.surnar@yash.com    E1     Permanent  [Java, React]
#
#                 Training Name Purpose to attend training  \
# 147  1218_CE_JavaBasics_Dec23    Upscaling the resources
# 148  1218_CE_JavaBasics_Dec23    Upscaling the resources
# 149  1218_CE_JavaBasics_Dec23    Upscaling the resources
# ...

# %%
df.head()
# Out:
#    S.No   Emp ID                     Name                       EmailID Grade  \
# 0     1  1014181             Mohd Manazir         mohd.manazir@yash.com    E2
# 1     2  1015340  Akash Sahadev Nandurkar      akash.nandurkar@yash.com    E1
# 2     3  1015860           Paritosh Dimri       paritosh.dimri@yash.com    E2
# 3     4  1009383      Krishnakant Bairagi  krishnakant.bairagi@yash.com    E3
# 4     5  1012704       Amol Shivaji Palve           amol.palve@yash.com    E2
#
#   Resource Type                                   Training Stack  \
# 0     Permanent  [Rest, Microservice, Docker, kubernetes, kafka]
# 1     Permanent  [Rest, Microservice, Docker, kubernetes, kafka]
# 2     Permanent  [Rest, Microservice, Docker, kubernetes, kafka]
# 3     Permanent                                          [Junit]
# 4     Permanent                                          [Junit]
#
#                                        Training Name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   S.No                        152 non-null    int64
#  1   Emp ID                      152 non-null    int64
#  2   Name                        152 non-null    object
#  3   EmailID                     152 non-null    object
#  4   Grade                       152 non-null    object
#  5   Resource Type               152 non-null    object
#  6   Training Stack              152 non-null    object
#  7   Training Name               152 non-null    object
#  8   Purpose to attend training  152 non-null    object
#  9   Training Duration(Days)     152 non-null    int64
#  10  Training Start Date         152 non-null    datetime64[ns]
#  11  Training End Date           152 non-null    datetime64[ns]
#  12  Current Skills              152 non-null    object
# ...

# %%
df['Training Stack']
# Out:
# 0      [Rest, Microservice, Docker, kubernetes, kafka]
# 1      [Rest, Microservice, Docker, kubernetes, kafka]
# 2      [Rest, Microservice, Docker, kubernetes, kafka]
# 3                                              [Junit]
# 4                                              [Junit]
#                             ...
# 147                                      [Java, React]
# 148                                      [Java, React]
# 149                                      [Java, React]
# 150                                      [Java, React]
# 151                                      [Java, React]
# Name: Training Stack, Length: 152, dtype: object

# %%
current_skills_column = df['Current Skills']

# Clean and create a list of unique skills
cleaned_skills = current_skills_column.str.split(r'\s*\+\s*|\s*,\s*|\s*and\s*|\s*;\s*|\s*\|\s*').explode().str.strip().tolist()

# Replace the 'Current Skills' column in the original DataFrame with the cleaned list
cleaned_skills
# Out:
# ['Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Microsoft',
#  'Microsoft',
#  'Microsoft',
#  'Microsoft',
#  'Microsoft',
#  'Legacy',
#  'Management',
#  'Java',
#  'Microsoft',
#  'Microsoft',
#  'Java',
#  'Legacy',
#  'Java',
#  'Java',
#  'Java',
#  'Management',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Oracle',
#  'Java',
#  'Java',
#  'Java',
#  'Java',
#  'Data & Analytics',
#  'DevOps',
#  'Data & Analytics',
#  'Java',
#  'Java',
#  'Java',
#  'Angular',
#  'Java (Backend)',
#  'Java (Backend)',
#  'Java (Backend)',
#  'Java',
# ...

# %%
df['Current Skills'] = df['Current Skills'].apply(clean_stack)

# %%
df['Current Skills'].iloc[86]
# Out:
# ['Java', 'Angular']

# %%
df['Upgraded Skills'] = df['Upgraded Skills'].apply(clean_stack)
df['Upgraded Skills']
# Out:
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#                  ...
# 147    [Fullstack, Java, React]
# 148    [Fullstack, Java, React]
# 149    [Fullstack, Java, React]
# 150    [Fullstack, Java, React]
# 151    [Fullstack, Java, React]
# Name: Upgraded Skills, Length: 152, dtype: object

# %%
df
# Out:
#      S.No   Emp ID                           Name  \
# 0       1  1014181                   Mohd Manazir
# 1       2  1015340        Akash Sahadev Nandurkar
# 2       3  1015860                 Paritosh Dimri
# 3       4  1009383            Krishnakant Bairagi
# 4       5  1012704             Amol Shivaji Palve
# ..    ...      ...                            ...
# 147   264  1100298         Mayur Madhukar Karmude
# 148   265  1100299     Charusheela Subhash Chavan
# 149   266  1100314     Varsha Chandrakant Aherkar
# 150   267  1100319  Shivdarshan Vishnukant Landge
# 151   268  1100332          Mahesh Tukaram Surnar
#
#                           EmailID Grade Resource Type  \
# 0           mohd.manazir@yash.com    E2     Permanent
# 1        akash.nandurkar@yash.com    E1     Permanent
# 2         paritosh.dimri@yash.com    E2     Permanent
# 3    krishnakant.bairagi@yash.com    E3     Permanent
# 4             amol.palve@yash.com    E2     Permanent
# ...

# %%
df.columns
# Out:
# Index(['S.No', 'Emp ID', 'Name', 'EmailID', 'Grade', 'Resource Type',
#        'Training Stack', 'Training Name', 'Purpose to attend training',
#        'Training Duration(Days)', 'Training Start Date', 'Training End Date',
#        'Current Skills', 'Upgraded Skills', 'Pre Assessment score',
#        'Final Score ', 'Current Allocation', 'Project', 'Current location',
#        'Status', 'Feedback /Remarks'],
#       dtype='object')

# %%
import numpy as np

# %%
mean_pre_score = 70
std_dev_pre_score = 10
df['Pre Assessment score'] = (np.random.normal(mean_pre_score, std_dev_pre_score, size=len(df))).astype(np.int64)

# Generate dummy data for Final Score (normal distribution with mean 75 and standard deviation 8)
mean_final_score = 75
std_dev_final_score = 8
df['Final Score '] = (np.random.normal(mean_final_score, std_dev_final_score, size=len(df))).astype(np.int64)

# %%
df.head()
# Out:
#    S.No   Emp ID                     Name                       EmailID Grade  \
# 0     1  1014181             Mohd Manazir         mohd.manazir@yash.com    E2
# 1     2  1015340  Akash Sahadev Nandurkar      akash.nandurkar@yash.com    E1
# 2     3  1015860           Paritosh Dimri       paritosh.dimri@yash.com    E2
# 3     4  1009383      Krishnakant Bairagi  krishnakant.bairagi@yash.com    E3
# 4     5  1012704       Amol Shivaji Palve           amol.palve@yash.com    E2
#
#   Resource Type                                   Training Stack  \
# 0     Permanent  [Rest, Microservice, Docker, kubernetes, kafka]
# 1     Permanent  [Rest, Microservice, Docker, kubernetes, kafka]
# 2     Permanent  [Rest, Microservice, Docker, kubernetes, kafka]
# 3     Permanent                                          [Junit]
# 4     Permanent                                          [Junit]
#
#                                        Training Name  \
# ...

# %%
df['Final Score ']
# Out:
# 0      62
# 1      81
# 2      80
# 3      66
# 4      71
#        ..
# 147    77
# 148    58
# 149    82
# 150    77
# 151    81
# Name: Final Score , Length: 152, dtype: int64

# %%
! pip install matplotlib
! pip install seaborn

# %%
df.columns
# Out:
# Index(['S.No', 'Emp ID', 'Name', 'EmailID', 'Grade', 'Resource Type',
#        'Training Stack', 'Training Name', 'Purpose to attend training',
#        'Training Duration(Days)', 'Training Start Date', 'Training End Date',
#        'Current Skills', 'Upgraded Skills', 'Pre Assessment score',
#        'Final Score ', 'Current Allocation', 'Project', 'Current location',
#        'Status', 'Feedback /Remarks'],
#       dtype='object')

# %%
def group_by_competency(df):
    return df.explode('Current Skills').groupby('Current Skills')

def group_by_skill(df):
    return df.groupby('Training Name')

def group_by_grade(df):
    return df.groupby('Grade')

def group_by_allocation(df):
    return df.groupby('Current Allocation')

def group_by_project(df):
    return df.groupby('Project')

def group_by_place(df):
    return df[['Current location', 'Name']].groupby('Current location')

def group_by_training_status(df):
    return df.groupby('Status')

def group_by_training_type(df):
    return df.groupby('Resource Type')

def group_by_upgraded_skills(df):
    return df.groupby('Upgraded Skills')

# %%
df.columns
# Out:
# Index(['S.No', 'Emp ID', 'Name', 'EmailID', 'Grade', 'Resource Type',
#        'Training Stack', 'Training Name', 'Purpose to attend training',
#        'Training Duration(Days)', 'Training Start Date', 'Training End Date',
#        'Current Skills', 'Upgraded Skills', 'Pre Assessment score',
#        'Final Score ', 'Current Allocation', 'Project', 'Current location',
#        'Status', 'Feedback /Remarks', 'Month'],
#       dtype='object')

# %%
group_by_place(df)

# %%
df['Status'].unique()
# Out:
# array(['In Progress', 'Completed'], dtype=object)

# %%
def training_record_by_status(df, status):
    return df[df['Status'] == status]

def training_resource_count_by_name(df):
    return df['Training Name'].value_counts()

def total_training_attended(df):
    return df.shape[0]

def competency_training_attended(df, competency):
    return df[df['Current Skills'].str.contains(competency, case=False, na=False)]

def top_performers_by_score(df, score_column):
    return df.loc[df.groupby('Name')[score_column].idxmax()]

# %%
training_record_by_status(df, 'In Progress')
# Out:
#     S.No   Emp ID                              Name  \
# 0      1  1014181                      Mohd Manazir
# 1      2  1015340           Akash Sahadev Nandurkar
# 2      3  1015860                    Paritosh Dimri
# 3      4  1009383               Krishnakant Bairagi
# 4      5  1012704                Amol Shivaji Palve
# 5      6  1013133                     Yogesh Nagora
# 6      7  1014127       Mayuri Nandkishorji Mundada
# 7      9  1014889           Vaibhav Prabhakar Shete
# 8     11  1017305      Devdatta Manoranjan Chilwant
# 9     12  1100929               Punam Shivaji Tonde
# 10    13  1100931             Omkar Maruti Lokhande
# 11    14  1100987              Nikita Nitin Umalkar
# 12    15  1016831                Fatima Riyaj Mulla
# 13    16  1101020             Gajanan Ganesh Dhotre
# 14    17  1100218            Rohit Bajirao Khairnar
# 15    18  1100837             Shubham Kishor Gajare
# 16    19  1100848              Vishal Ganesh Dhande
# ...

# %%
def developer_skills_competency(df):
    current_skills = df['Current Skills'].explode().unique()
    return current_skills

def associate_location_strength(df):
    return df.groupby('Current location').size()

def competency_strength_by_designation(df):
    exploded_df = df.explode('Current Skills')
    competency_counts = exploded_df.groupby(['Grade', 'Current Skills']).size().unstack(fill_value=0)
    return competency_counts

def top_associates_by_skills(df, skill):
    return df[df['Current Skills'].str.contains(skill, case=False, na=False)]

def training_status_overview(df):
    return df.groupby('Status').size()

def monthwise_training_completion(df, date_column):
    df[date_column] = pd.to_datetime(df[date_column])
    df['Month'] = df[date_column].dt.month
    return df.groupby('Month').size()

def final_training_growth(df):
    return df[['Pre Assessment score', 'Final Score ']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_group_by_competency(df):
    exploded_df = df.explode('Current Skills')
    grouped = exploded_df.groupby('Current Skills')['Name'].count()
    plt.figure(figsize=(10, 6))
    sns.barplot(x=grouped.index, y=grouped.values)
    plt.xticks(rotation=90)
    plt.xlabel('Current Skills')
    plt.ylabel('Count')
    plt.title('Count of Associates by Competency')
    plt.tight_layout()
    plt.show()

def plot_group_by_skill(df):
    grouped = group_by_skill(df)['Name'].count()
    plt.figure(figsize=(10, 6))
    sns.barplot(x=grouped.index, y=grouped.values)
    plt.xticks(rotation=90)
    plt.xlabel('Training Name')
    plt.ylabel('Count')
    plt.title('Count of Training Resources by Training Name')
    plt.tight_layout()
    plt.show()

def plot_group_by_grade(df):
    grouped = group_by_grade(df)['Name'].count()
    plt.figure(figsize=(8, 5))
    sns.barplot(x=grouped.index, y=grouped.values)
    plt.xlabel('Grade')
    plt.ylabel('Count')
    plt.title('Count of Associates by Grade')
    plt.tight_layout()
    plt.show()

def plot_group_by_allocation(df):
    grouped = group_by_allocation(df)['Name'].count()
    plt.figure(figsize=(8, 5))
    sns.barplot(x=grouped.index, y=grouped.values)
    plt.xlabel('Current Allocation')
    plt.ylabel('Count')
    plt.title('Count of Associates by Allocation')
    plt.tight_layout()
    plt.show()

def plot_group_by_project(df):
    grouped = group_by_project(df)['Name'].count().sort_values(ascending=False)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=grouped.index, y=grouped.values)
    plt.xticks(rotation=90)
    plt.xlabel('Project')
    plt.ylabel('Count')
    plt.title('Count of Associates by Project')
    plt.tight_layout()
    plt.show()


def plot_group_by_place(df):
    grouped = group_by_place(df)['Name'].count().sort_values(ascending=False)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=grouped.index, y=grouped.values)
    plt.xticks(rotation=90)
    plt.xlabel('Current location')
    plt.ylabel('Count')
    plt.title('Count of Associates by Location')
    plt.tight_layout()
    plt.show()

def plot_group_by_training_status(df):
    grouped = group_by_training_status(df)['Name'].count()
    plt.figure(figsize=(6, 4))
    grouped.plot(kind='pie', autopct='%1.1f%%')
    plt.ylabel('')
    plt.title('Training Status Distribution')
    plt.tight_layout()
    plt.show()

def plot_group_by_training_type(df):
    grouped = group_by_training_type(df)['Name'].count()
    plt.figure(figsize=(6, 4))
    grouped.plot(kind='pie', autopct='%1.1f%%')
    plt.ylabel('')
    plt.title('Training Type Distribution')
    plt.tight_layout()
    plt.show()

def plot_group_by_upgraded_skills(df):
    grouped = df.explode('Upgraded Skills').groupby('Upgraded Skills')['Name'].count().sort_values(ascending=False)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=grouped.index, y=grouped.values)
    plt.xticks(rotation=90)
    plt.xlabel('Upgraded Skills')
    plt.ylabel('Count')
    plt.title('Count of Associates by Upgraded Skills')
    plt.tight_layout()
    plt.show()

def plot_training_record_by_status(df):
    plt.figure(figsize=(6, 4))
    sns.countplot(x='Status', data=df)
    plt.title('Training Record Count by Status')
    plt.tight_layout()
    plt.show()


def plot_top_performers_by_score(df, score_column, top_n=10):
    top_performers = top_performers_by_score(df, score_column).head(top_n)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=top_performers['Name'], y=top_performers[score_column])
    plt.xticks(rotation=90)
    plt.xlabel('Associate')
    plt.ylabel(score_column)
    plt.title(f'Top {top_n} Performers by {score_column}')
    plt.tight_layout()
    plt.show()

# %%
grouped_competency = group_by_competency(df)
grouped_skill = group_by_skill(df)
grouped_grade = group_by_grade(df)
grouped_allocation = group_by_allocation(df)
grouped_project = group_by_project(df)
grouped_place = group_by_place(df)
grouped_training_status = group_by_training_status(df)
grouped_training_type = group_by_training_type(df)
grouped_upgraded_skills = group_by_upgraded_skills(df)

# Example usage of client requirements functions
in_progress_training_records = training_record_by_status(df, 'In progress')
training_resource_count = training_resource_count_by_name(df)
total_training_attendees = total_training_attended(df)
python_competency_training = competency_training_attended(df, 'Python')
top_performers_by_final_score = top_performers_by_score(df, 'Final Score ')

# Additional analysis functions usage
developer_skills = developer_skills_competency(df)
location_strength = associate_location_strength(df)
competency_strength = competency_strength_by_designation(df)
top_associates_python = top_associates_by_skills(df, 'Python')
training_status_distribution = training_status_overview(df)
monthwise_completion = monthwise_training_completion(df, 'Training End Date')
final_training_growth_data = final_training_growth(df)

# Print or display the results as needed
print(f"Total Training Attendees: {total_training_attendees}")
print(f"Developer Skills: {developer_skills}")
print(f"Location Strength: {location_strength}")
print(f"Top Associates in Python: {top_associates_python}")
print(f"Training Status Distribution: {training_status_distribution}")

# Example usage of plotting functions
plot_group_by_competency(df)
plot_group_by_skill(df)
plot_group_by_grade(df)
plot_group_by_allocation(df)
plot_group_by_project(df)
plot_group_by_place(df)
plot_group_by_training_status(df)
plot_group_by_training_type(df)
plot_group_by_upgraded_skills(df)
plot_training_record_by_status(df)
plot_top_performers_by_score(df, 'Final Score ')
# Out:
# Total Training Attendees: 152
# Developer Skills: ['Java' 'Microsoft' 'Legacy' 'Management' 'Oracle' 'Data & Analytics'
#  'DevOps' 'Angular' 'Backend' 'AWS' '.Net' 'Python']
# Location Strength: Current location
# Bangalore-BHIVE-DC (303)               2
# Gurgaon-DC (601)                       1
# Hyderabad-Mindspace I-DC (202)         6
# Hyderabad-Mindspace II-DC (203)        2
# Indore-Crystal IT Park-DC (102)        5
# Indore-Crystal IT Park-DC-II (103)    12
# Indore-YASH IT Park-SC-DC (104)       21
# Pune-Hinjewadi III-DC (404)           22
# Pune-Magarpatta-DC-II (405)           81
# dtype: int64
# Top Associates in Python: Empty DataFrame
# Columns: [S.No, Emp ID, Name, EmailID, Grade, Resource Type, Training Stack, Training Name, Purpose to attend training, Training Duration(Days), Training Start Date, Training End Date, Current Skills, Upgraded Skills, Pre Assessment score, Final Score , Current Allocation, Project, Current location, Status, Feedback /Remarks, Month]
# ...

# %%
df
# Out:
#      S.No   Emp ID                           Name  \
# 0       1  1014181                   Mohd Manazir
# 1       2  1015340        Akash Sahadev Nandurkar
# 2       3  1015860                 Paritosh Dimri
# 3       4  1009383            Krishnakant Bairagi
# 4       5  1012704             Amol Shivaji Palve
# ..    ...      ...                            ...
# 147   264  1100298         Mayur Madhukar Karmude
# 148   265  1100299     Charusheela Subhash Chavan
# 149   266  1100314     Varsha Chandrakant Aherkar
# 150   267  1100319  Shivdarshan Vishnukant Landge
# 151   268  1100332          Mahesh Tukaram Surnar
#
#                           EmailID Grade Resource Type  \
# 0           mohd.manazir@yash.com    E2     Permanent
# 1        akash.nandurkar@yash.com    E1     Permanent
# 2         paritosh.dimri@yash.com    E2     Permanent
# 3    krishnakant.bairagi@yash.com    E3     Permanent
# 4             amol.palve@yash.com    E2     Permanent
# ...

# %%
df.to_csv('cleaned_data.csv')
df.to_excel('cleaned_data.xlsx')

# %%
df.keys()
# Out:
# Index(['S.No', 'Emp ID', 'Name', 'EmailID', 'Grade', 'Resource Type',
#        'Training Stack', 'Training Name', 'Purpose to attend training',
#        'Training Duration(Days)', 'Training Start Date', 'Training End Date',
#        'Current Skills', 'Upgraded Skills', 'Pre Assessment score',
#        'Final Score ', 'Current Allocation', 'Project', 'Current location',
#        'Status', 'Feedback /Remarks', 'Month'],
#       dtype='object')

# %%
grouped_competency = group_by_competency(df)
list_dict = []
for x in grouped_competency:
    list_dict.append(dict(zip(df.keys(),x)))

list_dict
# Out:
# [{'S.No': '.Net',
#   'Emp ID':     S.No   Emp ID                        Name                    EmailID  \
#   88   198  1100174         Snehal Deepak Khade      snehal.khade@yash.com
#   89   202  1013907      Komal Balasaheb Gunjal      komal.gunjal@yash.com
#   90   203  1014064  Aishwarya Panditrao Kawade  aishwarya.kawade@yash.com
#
#      Grade Resource Type Training Stack            Training Name  \
#   88    E1     Permanent       [ORACLE]  0306_CL_SQL,PLSQL_Mar24
#   89    E1     Permanent       [ORACLE]  0306_CL_SQL,PLSQL_Mar24
#   90    E1     Permanent       [ORACLE]  0306_CL_SQL,PLSQL_Mar24
#
#      Purpose to attend training  Training Duration(Days)  ... Current Skills  \
#   88   Client specific training                       10  ...           .Net
#   89   Client specific training                       10  ...           .Net
#   90   Client specific training                       10  ...           .Net
#
# ...
